# %%
import os
from pprint import pprint
from dotenv import load_dotenv
from crucible import CrucibleClient

# %%
load_dotenv()
crucible_url = 'https://crucible.lbl.gov/api/v1'
crucible_apikey = os.environ.get('admin_apikey')
client = CrucibleClient(crucible_url, crucible_apikey)

# %%
# Fill out User Info 
user_info = {"first_name":"Morgan",
             "last_name":"Wall",
             "email":"xxx@lbl.gov",
             #"lbl_email":'', # optional
             "orcid":"0000-XXXX-XXXX-XXXX",
             #"employee_number":"", # optional
            "projects":['project_name', 'project2_name']}

# %%
# Add User to Crucible
client.add_user(user_info)

# %% [raw]
# # Add User to Other Projects
# client.add_user_to_project(orcid = '0000-XXXX-XXXX-XXXX', project_id = 'the-next-project')
